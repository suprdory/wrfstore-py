# %%
import os, glob
import wrftools as wrf
import wrfproc as wp
import pandas as pd
import numpy as np
import genutils as gu
from matplotlib import pyplot as plt
import importlib
importlib.reload(wrf)
importlib.reload(wp);

# %%
fpath=wrf.wopath('run_02_land_t10','wrfout_d03_2007-09-10_00:00:00')
tp=wrf.getWRF(fpath,'crr')
cc=wrf.getWRF(fpath,'cc')
x,y=wrf.getCoords(fpath)
# Out:
# Creating: run_02_land_t10/wrfout_d03_2007-09-10_00:00:00.crr.raw.npy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-e5c3b021fe86> in <module>
#       1 fpath=wrf.wopath('run_02_land_t10','wrfout_d03_2007-09-10_00:00:00')
# ----> 2 tp=wrf.getWRF(fpath,'crr')
#       3 cc=wrf.getWRF(fpath,'cc')
#       4 x,y=wrf.getCoords(fpath)
#
# /net/wrfstore6/disk1/nsparks/itc/python/wrftools.py in getWRF(wopath, varin, vtype, force, z)
#     101                 np.save(spath+ '.' + var + '.' + vtype, rainnc+rainc+rainsh)
#     102             elif z==0 and var=='crr':
# --> 103                 ccr=wrfout2var2d(wopath,'RAINCV')
#     104                 np.save(spath+ '.' + var + '.' + vtype, ccr)
#     105
#
# /net/wrfstore6/disk1/nsparks/itc/python/wrftools.py in wrfout2var2d(ncfname, var)
#     372 # returns wrfout 2d var as np array (lon,lat,z), ignores tx > 0
# ...

# %%
xr=200
gu.imshowxy(y/1000,x/1000,tp)
plt.xlim((-xr,xr))
plt.ylim((-xr,xr));

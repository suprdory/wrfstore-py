# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import os, glob
import wrftools as wrf

# rpath1='/net/wrfstore6/disk1/nsparks/itc/run/run_CTRL_10m/wrfout_d03*'
#run='/net/wrfstore6/disk1/nsparks/itc/run/run_CTRL_SWexe/wrfout_d03*'

# rpath1='/net/wrfstore6/disk1/nsparks/itc/run/run_land_t06/wrfout_d03*'
# rpath2='/net/wrfstore6/disk1/nsparks/itc/run/run_land_t06_10/wrfout_d03*'

run='run_CTRL'
flist=wrf.getflist(run)

# %%
P=wrf.getWRF(run,flist[24],'P')

# %%
plt.pcolormesh(P)
plt.plot(400,400,'rx')

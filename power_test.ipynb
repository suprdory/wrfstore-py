# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.linspace(-1,1,1000)
x[x==0]==[]
# Out:
# array([], dtype=bool)

# %%
a=np.linspace(0,4,81)

# %%
ys=[]
for an in a:
    ys.append(x**an)
# Out:
# <ipython-input-44-135e8022c5ac>:3: RuntimeWarning: invalid value encountered in power
#   ys.append(x**an)
# <ipython-input-44-135e8022c5ac>:3: RuntimeWarning: invalid value encountered in sqrt
#   ys.append(x**an)

# %%
for y in ys:
    plt.plot(x,y)

# %%
np.power(-0.5,1.5)
# Out:
# <ipython-input-42-7c735e14e4c9>:1: RuntimeWarning: invalid value encountered in power
#   np.power(-0.5,1.5)
# nan
